# %% [markdown]
# # Analysis of Flight Delays
# ## by Robert Hofstetter
#
# ## Preliminary Wrangling
#
# > The data for this analysis was obtained from the [Bureau of Transportation Staticis](https://www.transtats.bts.gov/DL_SelectFields.asp?Table_ID=236). All domestic United States regions for years 2018 and 2019 were download by month and concatenated together outside of this notebook into two separate files for each year. It is a rather large set of data so I've separated the wrangling in order to speed processing of cells in the analysis. The data is then aggregated by day and saved to file.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import os.path
from scipy import stats

# %matplotlib inline

# %% [markdown]
# # Gather
# Check if the cleaned file exists and load it directly. Otherwise, load one file for each year of flight data

# %%
flights_2018 = pd.read_csv('flights_2018.csv')
flights_2019 = pd.read_csv('flights_2019.csv')
delayed_flights = pd.concat([flights_2018, flights_2019])

# %% [markdown]
# # Assess
# Examine the cleanliness and tidiness of the data

# %%
delayed_flights.head()
# Out:
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 0  2018        4     11            18            7  2018-11-18
# 1  2018        4     11            20            2  2018-11-20
# 2  2018        4     11            21            3  2018-11-21
# 3  2018        4     11            22            4  2018-11-22
# 4  2018        4     11            23            5  2018-11-23
#
#   OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN  ... ARR_DELAY  \
# 0                9E   N909XJ               5044    DTW  ...     -21.0
# 1                9E   N600LR               5044    DTW  ...      -4.0
# 2                9E   N903XJ               5044    DTW  ...     -26.0
# 3                9E   N326PQ               5044    DTW  ...       5.0
# 4                9E   N324PQ               5044    DTW  ...      -5.0
#
#   CANCELLED AIR_TIME DISTANCE CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0       0.0     82.0    534.0           NaN            NaN        NaN
# 1       0.0     83.0    534.0           NaN            NaN        NaN
# 2       0.0     85.0    534.0           NaN            NaN        NaN
# 3       0.0     81.0    534.0           NaN            NaN        NaN
# 4       0.0     92.0    534.0           NaN            NaN        NaN
#
#    SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 29
# 0             NaN                  NaN          NaN
# 1             NaN                  NaN          NaN
# 2             NaN                  NaN          NaN
# 3             NaN                  NaN          NaN
# 4             NaN                  NaN          NaN
#
# [5 rows x 30 columns]

# %%
delayed_flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14635483 entries, 0 to 7422036
# Data columns (total 30 columns):
# YEAR                   int64
# QUARTER                int64
# MONTH                  int64
# DAY_OF_MONTH           int64
# DAY_OF_WEEK            int64
# FL_DATE                object
# OP_UNIQUE_CARRIER      object
# TAIL_NUM               object
# OP_CARRIER_FL_NUM      int64
# ORIGIN                 object
# ORIGIN_CITY_NAME       object
# ORIGIN_STATE_ABR       object
# DEST                   object
# DEST_CITY_NAME         object
# DEST_STATE_ABR         object
# CRS_DEP_TIME           int64
# DEP_TIME               float64
# DEP_DELAY              float64
# CRS_ARR_TIME           int64
# ARR_TIME               float64
# ARR_DELAY              float64
# CANCELLED              float64
# AIR_TIME               float64
# DISTANCE               float64
# CARRIER_DELAY          float64
# WEATHER_DELAY          float64
# NAS_DELAY              float64
# SECURITY_DELAY         float64
# LATE_AIRCRAFT_DELAY    float64
# Unnamed: 29            float64
# dtypes: float64(13), int64(8), object(9)
# memory usage: 3.4+ GB

# %%
delayed_flights[['CRS_DEP_TIME','DEP_TIME']].head()
# Out:
#    CRS_DEP_TIME  DEP_TIME
# 0          1555    1550.0
# 1          1555    1605.0
# 2          1555    1549.0
# 3          1555    1550.0
# 4          1555    1551.0

# %%
delayed_flights['Unnamed: 29'].unique()
# Out:
# array([nan])

# %%
delayed_flights['DEP_DELAY'].unique()
# Out:
# array([  -5.,   10.,   -6., ..., 1637., 1566., 1387.])

# %%
delayed_flights['ARR_DELAY'].unique()
# Out:
# array([ -21.,   -4.,  -26., ..., 1448., 1354., 1398.])

# %%
delayed_flights['OP_UNIQUE_CARRIER'].value_counts()
# Out:
# WN    2716498
# DL    1941269
# AA    1863594
# OO    1610582
# UA    1247475
# YX     645239
# MQ     623008
# B6     602421
# OH     567761
# AS     510577
# 9E     503049
# YV     443026
# NK     381023
# EV     337573
# F9     255578
# G4     201526
# HA     167614
# VX      17670
# Name: OP_UNIQUE_CARRIER, dtype: int64

# %%
delayed_flights[['DEP_DELAY','ARR_DELAY','CARRIER_DELAY','WEATHER_DELAY','NAS_DELAY','SECURITY_DELAY','LATE_AIRCRAFT_DELAY']].describe()
# Out:
#           DEP_DELAY     ARR_DELAY  CARRIER_DELAY  WEATHER_DELAY     NAS_DELAY  \
# count  1.438814e+07  1.434464e+07   2.741963e+06   2.741963e+06  2.741963e+06
# mean   1.045305e+01  5.234164e+00   2.030295e+01   3.720537e+00  1.624139e+01
# std    4.697056e+01  4.906834e+01   6.266330e+01   3.121780e+01  3.785268e+01
# min   -1.220000e+02 -1.200000e+02   0.000000e+00   0.000000e+00  0.000000e+00
# 25%   -5.000000e+00 -1.500000e+01   0.000000e+00   0.000000e+00  0.000000e+00
# 50%   -2.000000e+00 -6.000000e+00   0.000000e+00   0.000000e+00  3.000000e+00
# 75%    7.000000e+00  8.000000e+00   1.700000e+01   0.000000e+00  2.000000e+01
# max    2.710000e+03  2.695000e+03   2.695000e+03   2.692000e+03  1.848000e+03
#
#        SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# count    2.741963e+06         2.741963e+06
# mean     9.482805e-02         2.653755e+01
# std      3.268848e+00         5.168649e+01
# min      0.000000e+00         0.000000e+00
# 25%      0.000000e+00         0.000000e+00
# 50%      0.000000e+00         3.000000e+00
# 75%      0.000000e+00         3.200000e+01
# max      1.078000e+03         2.454000e+03

# %%
delayed_flights[delayed_flights['DEP_DELAY'] == 2710]
# Out:
#          YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK     FL_DATE  \
# 4329216  2018        3      7             5            4  2018-07-05
# 822649   2019        4     12            12            4  2019-12-12
#
#         OP_UNIQUE_CARRIER TAIL_NUM  OP_CARRIER_FL_NUM ORIGIN  ... ARR_DELAY  \
# 4329216                OO   N264SY               4690    CLT  ...    2692.0
# 822649                 OO   N727SK               3253    SYR  ...    2695.0
#
#         CANCELLED AIR_TIME DISTANCE CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 4329216       0.0     79.0    541.0           0.0         2692.0        0.0
# 822649        0.0    107.0    607.0        2695.0            0.0        0.0
#
#          SECURITY_DELAY  LATE_AIRCRAFT_DELAY  Unnamed: 29
# 4329216             0.0                  0.0          NaN
# 822649              0.0                  0.0          NaN
#
# [2 rows x 30 columns]

# %% [markdown]
# # Data Assessment
# The data is fairly clean and tidy but there are a few things that need to be addressed:
# 1. There are cancelled and early flights which do not register a delay
# 2. Double counting of delays from including records having late aircraft
# 3. There is an unnamed column that has no data and thus no value
# 4. Arrival time and scheduled arrival time are not the same data types
# 5. Departure time and scheduled departure time are not the same data types
# 6. Columns TAIL_NUM and OP_CARRIER_FL_NUM are not useful for this exercise
# 7. Delays greater than a day are really cancelled flights
# 8. There are early departures and arrivals represented as negative values
#
# # Clean

# %%
# Fix the data types of the scheduled times to match the data type of actual times
delayed_flights['CRS_ARR_TIME'] = delayed_flights['ARR_TIME'].astype('float')
delayed_flights['CRS_DEP_TIME'] = delayed_flights['DEP_TIME'].astype('float')

# %%
# Drop all delays greater than 1 day because those would really be considered cancelled and rebooked
delayed_flights = delayed_flights[delayed_flights['DEP_DELAY'] < 1440]

# %%
# Drop cancelled flights
delayed_flights = delayed_flights[delayed_flights['CANCELLED'] == 0]

# %%
# Retain only flights that had a delay in either depature or arrival
delayed_flights = delayed_flights[(delayed_flights['DEP_DELAY'] > 0) | (delayed_flights['ARR_DELAY'] > 0)]

# %%
# Drop the late aircraft delays that generally indicate the previous flight was delayed to avoid double counting
delayed_flights = delayed_flights[delayed_flights['LATE_AIRCRAFT_DELAY'] == 0]

# %%
# Drop unused columns
delayed_flights = delayed_flights.drop(columns=['Unnamed: 29', 'TAIL_NUM', 'OP_CARRIER_FL_NUM', 'CANCELLED', 'LATE_AIRCRAFT_DELAY'])

# %%
delayed_flights[['DEP_DELAY','ARR_DELAY','CARRIER_DELAY','WEATHER_DELAY','NAS_DELAY','SECURITY_DELAY']].describe()
# Out:
#           DEP_DELAY     ARR_DELAY  CARRIER_DELAY  WEATHER_DELAY     NAS_DELAY  \
# count  1.321839e+06  1.321839e+06   1.321839e+06   1.321839e+06  1.321839e+06
# mean   4.906143e+01  5.999704e+01   3.007885e+01   5.215891e+00  2.456486e+01
# std    9.233441e+01  8.811010e+01   7.619636e+01   3.804508e+01  4.588410e+01
# min   -4.700000e+01  1.500000e+01   0.000000e+00   0.000000e+00  0.000000e+00
# 25%    0.000000e+00  2.100000e+01   0.000000e+00   0.000000e+00  0.000000e+00
# 50%    2.500000e+01  3.300000e+01   1.000000e+00   0.000000e+00  1.600000e+01
# 75%    5.900000e+01  6.300000e+01   3.000000e+01   0.000000e+00  2.900000e+01
# max    1.439000e+03  1.540000e+03   1.458000e+03   1.431000e+03  1.515000e+03
#
#        SECURITY_DELAY
# count    1.321839e+06
# mean     1.374396e-01
# std      3.861963e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      1.048000e+03

# %%
print(delayed_flights['DEP_DELAY'].min())
print(delayed_flights['DEP_DELAY'].max())
print(delayed_flights['ARR_DELAY'].min())
print(delayed_flights['ARR_DELAY'].max())
# Out:
# -47.0
# 1439.0
# 15.0
# 1540.0

# %%
# For analysis of delays we cannot have negative values which really represent the opposite of a delay
delayed_flights.loc[delayed_flights['DEP_DELAY'] < 0, 'DEP_DELAY'] = 0
delayed_flights.loc[delayed_flights['ARR_DELAY'] < 0, 'ARR_DELAY'] = 0
print(delayed_flights['DEP_DELAY'].min())
print(delayed_flights['DEP_DELAY'].max())
print(delayed_flights['ARR_DELAY'].min())
print(delayed_flights['ARR_DELAY'].max())
# Out:
# 0.0
# 1439.0
# 15.0
# 1540.0

# %%
# Create an aggregation of count of flights by carrier and mean departure delay
carrier_agg = delayed_flights.groupby(['YEAR', 'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'OP_UNIQUE_CARRIER', 'ORIGIN', 'DEST']) \
    .agg({'DEP_DELAY':['count', 'mean', 'min', 'max'], 'ARR_DELAY':['mean', 'min', 'max'], 'DISTANCE':['mean']})

# %%
# Rename the columns and reset the index after aggregating
carrier_agg.columns = ['FLIGHTS', 'DEP_DELAY_MEAN', 'DEP_DELAY_MIN', 'DEP_DELAY_MAX', 'ARR_DELAY_MEAN', 'ARR_DELAY_MIN', 'ARR_DELAY_MAX', 'MEAN_DISTANCE']
carrier_agg.reset_index()
# Out:
#          YEAR  MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST  \
# 0        2018      1             1            1                9E    AGS  ATL
# 1        2018      1             1            1                9E    ATL  AEX
# 2        2018      1             1            1                9E    ATL  BMI
# 3        2018      1             1            1                9E    ATL  CHS
# 4        2018      1             1            1                9E    ATL  CSG
# ...       ...    ...           ...          ...               ...    ...  ...
# 1060601  2019     12            31            2                YX    PWM  DCA
# 1060602  2019     12            31            2                YX    PWM  PHL
# 1060603  2019     12            31            2                YX    RDU  EWR
# 1060604  2019     12            31            2                YX    RDU  RSW
# 1060605  2019     12            31            2                YX    SRQ  DCA
#
#          FLIGHTS  DEP_DELAY_MEAN  DEP_DELAY_MIN  DEP_DELAY_MAX  \
# 0              1            32.0           32.0           32.0
# 1              1            55.0           55.0           55.0
# 2              1             0.0            0.0            0.0
# 3              1            80.0           80.0           80.0
# 4              1           102.0          102.0          102.0
# ...          ...             ...            ...            ...
# 1060601        1           191.0          191.0          191.0
# 1060602        1           123.0          123.0          123.0
# 1060603        1             0.0            0.0            0.0
# 1060604        1             0.0            0.0            0.0
# 1060605        1            22.0           22.0           22.0
#
#          ARR_DELAY_MEAN  ARR_DELAY_MIN  ARR_DELAY_MAX  MEAN_DISTANCE
# 0                  30.0           30.0           30.0          143.0
# 1                  43.0           43.0           43.0          500.0
# 2                  53.0           53.0           53.0          533.0
# 3                  72.0           72.0           72.0          259.0
# 4                 139.0          139.0          139.0           83.0
# ...                 ...            ...            ...            ...
# 1060601           219.0          219.0          219.0          482.0
# 1060602           181.0          181.0          181.0          364.0
# 1060603            16.0           16.0           16.0          416.0
# 1060604            26.0           26.0           26.0          667.0
# 1060605            18.0           18.0           18.0          851.0
#
# [1060606 rows x 15 columns]

# %%
carrier_agg[carrier_agg['FLIGHTS'] > 10]
# Out:
#                                                                    FLIGHTS  \
# YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST
# 2018 1     23           2           DL                ATL    LGA        11
#      2     21           3           AS                SEA    ANC        12
#      3     27           2           AS                SEA    ANC        11
#      4     3            2           DL                MSP    ATL        11
#            25           3           DL                ATL    LGA        13
#                                     UA                ORD    LGA        12
#            30           1           AS                SEA    ANC        12
#      5     24           4           AS                SEA    LAX        11
#      8     21           2           AA                ORD    LGA        11
#            25           6           AS                SEA    ANC        13
#      9     10           1           DL                ATL    LGA        12
#      10    18           4           YX                DCA    LGA        11
#            22           1           AS                LAX    SEA        12
#      11    6            2           YX                DCA    LGA        11
#            9            5           DL                MCO    ATL        11
#            13           2           UA                ORD    LGA        12
#            14           3           DL                LGA    ATL        13
#            28           3           DL                ATL    LGA        12
#                                     UA                ORD    LGA        13
#      12    13           4           YX                LGA    DCA        11
#            18           2           UA                ORD    LGA        12
#                                     YX                DCA    LGA        13
#            21           5           AA                DFW    LGA        11
# 2019 1     10           4           DL                ATL    LGA        14
#            17           4           YX                DCA    LGA        11
#            22           2           YX                DCA    LGA        13
#            23           3           YX                DCA    LGA        11
#      2     5            2           AS                SEA    ANC        11
#      3     1            5           DL                ATL    LGA        11
#                                     UA                ORD    LGA        11
#      4     22           1           YX                DCA    LGA        11
#      5     29           3           DL                ATL    LAX        12
#      6     16           7           AA                ORD    DFW        11
#      9     12           4           AA                DFW    ORD        11
#      11    18           1           DL                ATL    LGA        11
#            27           3           B6                JFK    LAX        12
#            30           6           AA                ORD    DFW        11
#      12    2            1           AS                SEA    SFO        11
#            15           7           B6                JFK    LAX        13
#
#                                                                    DEP_DELAY_MEAN  \
# YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST
# 2018 1     23           2           DL                ATL    LGA        51.000000
#      2     21           3           AS                SEA    ANC         9.000000
#      3     27           2           AS                SEA    ANC         4.363636
#      4     3            2           DL                MSP    ATL         9.727273
#            25           3           DL                ATL    LGA        50.692308
#                                     UA                ORD    LGA        79.166667
#            30           1           AS                SEA    ANC         2.000000
#      5     24           4           AS                SEA    LAX        30.272727
#      8     21           2           AA                ORD    LGA        46.000000
#            25           6           AS                SEA    ANC         6.769231
#      9     10           1           DL                ATL    LGA        33.416667
#      10    18           4           YX                DCA    LGA        10.636364
#            22           1           AS                LAX    SEA        66.166667
#      11    6            2           YX                DCA    LGA        25.636364
#            9            5           DL                MCO    ATL        47.272727
#            13           2           UA                ORD    LGA        44.250000
#            14           3           DL                LGA    ATL         0.846154
#            28           3           DL                ATL    LGA        53.833333
#                                     UA                ORD    LGA        62.384615
#      12    13           4           YX                LGA    DCA        10.090909
#            18           2           UA                ORD    LGA        14.916667
#                                     YX                DCA    LGA         4.692308
#            21           5           AA                DFW    LGA        17.000000
# 2019 1     10           4           DL                ATL    LGA        52.357143
#            17           4           YX                DCA    LGA        16.727273
#            22           2           YX                DCA    LGA         7.153846
#            23           3           YX                DCA    LGA        36.545455
#      2     5            2           AS                SEA    ANC        44.818182
#      3     1            5           DL                ATL    LGA        89.181818
#                                     UA                ORD    LGA        59.000000
#      4     22           1           YX                DCA    LGA        23.000000
#      5     29           3           DL                ATL    LAX        21.166667
#      6     16           7           AA                ORD    DFW        60.636364
#      9     12           4           AA                DFW    ORD       112.909091
#      11    18           1           DL                ATL    LGA        58.909091
#            27           3           B6                JFK    LAX         3.416667
#            30           6           AA                ORD    DFW         6.545455
#      12    2            1           AS                SEA    SFO        92.181818
#            15           7           B6                JFK    LAX        20.692308
#
#                                                                    DEP_DELAY_MIN  \
# YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST
# 2018 1     23           2           DL                ATL    LGA            17.0
#      2     21           3           AS                SEA    ANC             0.0
#      3     27           2           AS                SEA    ANC             0.0
#      4     3            2           DL                MSP    ATL             0.0
#            25           3           DL                ATL    LGA             0.0
#                                     UA                ORD    LGA             0.0
#            30           1           AS                SEA    ANC             0.0
#      5     24           4           AS                SEA    LAX             0.0
#      8     21           2           AA                ORD    LGA             0.0
#            25           6           AS                SEA    ANC             0.0
#      9     10           1           DL                ATL    LGA             0.0
#      10    18           4           YX                DCA    LGA             0.0
#            22           1           AS                LAX    SEA             0.0
#      11    6            2           YX                DCA    LGA             0.0
#            9            5           DL                MCO    ATL            15.0
#            13           2           UA                ORD    LGA             0.0
#            14           3           DL                LGA    ATL             0.0
#            28           3           DL                ATL    LGA            31.0
#                                     UA                ORD    LGA             0.0
#      12    13           4           YX                LGA    DCA             0.0
#            18           2           UA                ORD    LGA             0.0
#                                     YX                DCA    LGA             0.0
#            21           5           AA                DFW    LGA             0.0
# 2019 1     10           4           DL                ATL    LGA             0.0
#            17           4           YX                DCA    LGA             0.0
#            22           2           YX                DCA    LGA             0.0
#            23           3           YX                DCA    LGA             0.0
#      2     5            2           AS                SEA    ANC            12.0
#      3     1            5           DL                ATL    LGA            23.0
#                                     UA                ORD    LGA             0.0
#      4     22           1           YX                DCA    LGA             0.0
#      5     29           3           DL                ATL    LAX             0.0
#      6     16           7           AA                ORD    DFW             0.0
#      9     12           4           AA                DFW    ORD             0.0
#      11    18           1           DL                ATL    LGA            19.0
#            27           3           B6                JFK    LAX             0.0
#            30           6           AA                ORD    DFW             0.0
#      12    2            1           AS                SEA    SFO            21.0
#            15           7           B6                JFK    LAX             0.0
#
#                                                                    DEP_DELAY_MAX  \
# YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST
# 2018 1     23           2           DL                ATL    LGA            85.0
#      2     21           3           AS                SEA    ANC            50.0
#      3     27           2           AS                SEA    ANC            18.0
#      4     3            2           DL                MSP    ATL            37.0
#            25           3           DL                ATL    LGA            76.0
#                                     UA                ORD    LGA           224.0
#            30           1           AS                SEA    ANC            12.0
#      5     24           4           AS                SEA    LAX           159.0
#      8     21           2           AA                ORD    LGA           122.0
#            25           6           AS                SEA    ANC            54.0
#      9     10           1           DL                ATL    LGA           111.0
#      10    18           4           YX                DCA    LGA            46.0
#            22           1           AS                LAX    SEA           194.0
#      11    6            2           YX                DCA    LGA            76.0
#            9            5           DL                MCO    ATL           134.0
#            13           2           UA                ORD    LGA           141.0
#            14           3           DL                LGA    ATL             6.0
#            28           3           DL                ATL    LGA            75.0
#                                     UA                ORD    LGA           185.0
#      12    13           4           YX                LGA    DCA            61.0
#            18           2           UA                ORD    LGA            78.0
#                                     YX                DCA    LGA            24.0
#            21           5           AA                DFW    LGA            83.0
# 2019 1     10           4           DL                ATL    LGA           131.0
#            17           4           YX                DCA    LGA            56.0
#            22           2           YX                DCA    LGA            50.0
#            23           3           YX                DCA    LGA           100.0
#      2     5            2           AS                SEA    ANC            90.0
#      3     1            5           DL                ATL    LGA           160.0
#                                     UA                ORD    LGA           166.0
#      4     22           1           YX                DCA    LGA            81.0
#      5     29           3           DL                ATL    LAX            54.0
#      6     16           7           AA                ORD    DFW           212.0
#      9     12           4           AA                DFW    ORD           483.0
#      11    18           1           DL                ATL    LGA           166.0
#            27           3           B6                JFK    LAX            24.0
#            30           6           AA                ORD    DFW            20.0
#      12    2            1           AS                SEA    SFO           181.0
#            15           7           B6                JFK    LAX           103.0
#
#                                                                    ARR_DELAY_MEAN  \
# YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST
# 2018 1     23           2           DL                ATL    LGA        41.454545
#      2     21           3           AS                SEA    ANC        41.833333
#      3     27           2           AS                SEA    ANC        27.818182
#      4     3            2           DL                MSP    ATL        39.727273
#            25           3           DL                ATL    LGA        57.923077
#                                     UA                ORD    LGA        94.333333
#            30           1           AS                SEA    ANC        27.916667
#      5     24           4           AS                SEA    LAX        56.363636
#      8     21           2           AA                ORD    LGA        68.000000
#            25           6           AS                SEA    ANC        34.538462
#      9     10           1           DL                ATL    LGA        42.166667
#      10    18           4           YX                DCA    LGA        50.000000
#            22           1           AS                LAX    SEA        80.666667
#      11    6            2           YX                DCA    LGA        45.454545
#            9            5           DL                MCO    ATL        65.727273
#            13           2           UA                ORD    LGA        66.583333
#            14           3           DL                LGA    ATL        26.615385
#            28           3           DL                ATL    LGA        67.500000
#                                     UA                ORD    LGA        91.461538
#      12    13           4           YX                LGA    DCA        34.909091
#            18           2           UA                ORD    LGA        35.083333
#                                     YX                DCA    LGA        39.461538
#            21           5           AA                DFW    LGA        41.818182
# 2019 1     10           4           DL                ATL    LGA        74.928571
#            17           4           YX                DCA    LGA        57.000000
#            22           2           YX                DCA    LGA        45.769231
#            23           3           YX                DCA    LGA        57.727273
#      2     5            2           AS                SEA    ANC        48.454545
#      3     1            5           DL                ATL    LGA        83.909091
#                                     UA                ORD    LGA        80.727273
#      4     22           1           YX                DCA    LGA        51.181818
#      5     29           3           DL                ATL    LAX        46.500000
#      6     16           7           AA                ORD    DFW        82.727273
#      9     12           4           AA                DFW    ORD       128.363636
#      11    18           1           DL                ATL    LGA        67.090909
#            27           3           B6                JFK    LAX        41.666667
#            30           6           AA                ORD    DFW        29.727273
#      12    2            1           AS                SEA    SFO        92.909091
#            15           7           B6                JFK    LAX        48.384615
#
#                                                                    ARR_DELAY_MIN  \
# YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST
# 2018 1     23           2           DL                ATL    LGA            16.0
#      2     21           3           AS                SEA    ANC            20.0
#      3     27           2           AS                SEA    ANC            16.0
#      4     3            2           DL                MSP    ATL            15.0
#            25           3           DL                ATL    LGA            17.0
#                                     UA                ORD    LGA            21.0
#            30           1           AS                SEA    ANC            20.0
#      5     24           4           AS                SEA    LAX            24.0
#      8     21           2           AA                ORD    LGA            17.0
#            25           6           AS                SEA    ANC            15.0
#      9     10           1           DL                ATL    LGA            17.0
#      10    18           4           YX                DCA    LGA            17.0
#            22           1           AS                LAX    SEA            18.0
#      11    6            2           YX                DCA    LGA            25.0
#            9            5           DL                MCO    ATL            30.0
#            13           2           UA                ORD    LGA            15.0
#            14           3           DL                LGA    ATL            15.0
#            28           3           DL                ATL    LGA            42.0
#                                     UA                ORD    LGA            15.0
#      12    13           4           YX                LGA    DCA            19.0
#            18           2           UA                ORD    LGA            15.0
#                                     YX                DCA    LGA            21.0
#            21           5           AA                DFW    LGA            21.0
# 2019 1     10           4           DL                ATL    LGA            16.0
#            17           4           YX                DCA    LGA            22.0
#            22           2           YX                DCA    LGA            19.0
#            23           3           YX                DCA    LGA            16.0
#      2     5            2           AS                SEA    ANC            16.0
#      3     1            5           DL                ATL    LGA            27.0
#                                     UA                ORD    LGA            34.0
#      4     22           1           YX                DCA    LGA            18.0
#      5     29           3           DL                ATL    LAX            28.0
#      6     16           7           AA                ORD    DFW            15.0
#      9     12           4           AA                DFW    ORD            17.0
#      11    18           1           DL                ATL    LGA            17.0
#            27           3           B6                JFK    LAX            17.0
#            30           6           AA                ORD    DFW            15.0
#      12    2            1           AS                SEA    SFO            34.0
#            15           7           B6                JFK    LAX            16.0
#
#                                                                    ARR_DELAY_MAX  \
# YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST
# 2018 1     23           2           DL                ATL    LGA            58.0
#      2     21           3           AS                SEA    ANC            89.0
#      3     27           2           AS                SEA    ANC            42.0
#      4     3            2           DL                MSP    ATL            98.0
#            25           3           DL                ATL    LGA            88.0
#                                     UA                ORD    LGA           225.0
#            30           1           AS                SEA    ANC            46.0
#      5     24           4           AS                SEA    LAX           186.0
#      8     21           2           AA                ORD    LGA           138.0
#            25           6           AS                SEA    ANC            63.0
#      9     10           1           DL                ATL    LGA           122.0
#      10    18           4           YX                DCA    LGA            88.0
#            22           1           AS                LAX    SEA           206.0
#      11    6            2           YX                DCA    LGA            78.0
#            9            5           DL                MCO    ATL           136.0
#            13           2           UA                ORD    LGA           135.0
#            14           3           DL                LGA    ATL            41.0
#            28           3           DL                ATL    LGA           108.0
#                                     UA                ORD    LGA           246.0
#      12    13           4           YX                LGA    DCA            91.0
#            18           2           UA                ORD    LGA            67.0
#                                     YX                DCA    LGA            81.0
#            21           5           AA                DFW    LGA           115.0
# 2019 1     10           4           DL                ATL    LGA           129.0
#            17           4           YX                DCA    LGA           135.0
#            22           2           YX                DCA    LGA            82.0
#            23           3           YX                DCA    LGA            99.0
#      2     5            2           AS                SEA    ANC           104.0
#      3     1            5           DL                ATL    LGA           141.0
#                                     UA                ORD    LGA           176.0
#      4     22           1           YX                DCA    LGA            95.0
#      5     29           3           DL                ATL    LAX            70.0
#      6     16           7           AA                ORD    DFW           247.0
#      9     12           4           AA                DFW    ORD           475.0
#      11    18           1           DL                ATL    LGA           147.0
#            27           3           B6                JFK    LAX            68.0
#            30           6           AA                ORD    DFW            60.0
#      12    2            1           AS                SEA    SFO           179.0
#            15           7           B6                JFK    LAX           134.0
#
#                                                                    MEAN_DISTANCE
# YEAR MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST
# 2018 1     23           2           DL                ATL    LGA           762.0
#      2     21           3           AS                SEA    ANC          1448.0
#      3     27           2           AS                SEA    ANC          1448.0
#      4     3            2           DL                MSP    ATL           907.0
#            25           3           DL                ATL    LGA           762.0
#                                     UA                ORD    LGA           733.0
#            30           1           AS                SEA    ANC          1448.0
#      5     24           4           AS                SEA    LAX           954.0
#      8     21           2           AA                ORD    LGA           733.0
#            25           6           AS                SEA    ANC          1448.0
#      9     10           1           DL                ATL    LGA           762.0
#      10    18           4           YX                DCA    LGA           214.0
#            22           1           AS                LAX    SEA           954.0
#      11    6            2           YX                DCA    LGA           214.0
#            9            5           DL                MCO    ATL           404.0
#            13           2           UA                ORD    LGA           733.0
#            14           3           DL                LGA    ATL           762.0
#            28           3           DL                ATL    LGA           762.0
#                                     UA                ORD    LGA           733.0
#      12    13           4           YX                LGA    DCA           214.0
#            18           2           UA                ORD    LGA           733.0
#                                     YX                DCA    LGA           214.0
#            21           5           AA                DFW    LGA          1389.0
# 2019 1     10           4           DL                ATL    LGA           762.0
#            17           4           YX                DCA    LGA           214.0
#            22           2           YX                DCA    LGA           214.0
#            23           3           YX                DCA    LGA           214.0
#      2     5            2           AS                SEA    ANC          1448.0
#      3     1            5           DL                ATL    LGA           762.0
#                                     UA                ORD    LGA           733.0
#      4     22           1           YX                DCA    LGA           214.0
#      5     29           3           DL                ATL    LAX          1947.0
#      6     16           7           AA                ORD    DFW           801.0
#      9     12           4           AA                DFW    ORD           801.0
#      11    18           1           DL                ATL    LGA           762.0
#            27           3           B6                JFK    LAX          2475.0
#            30           6           AA                ORD    DFW           801.0
#      12    2            1           AS                SEA    SFO           679.0
#            15           7           B6                JFK    LAX          2475.0

# %%
carrier_agg.to_csv('delayed_flights.csv', index=True)
